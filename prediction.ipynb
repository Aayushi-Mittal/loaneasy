# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GroupShuffleSplit

# Classification models
import xgboost as xgb

from tqdm import tqdm_notebook

import warnings
warnings.simplefilter('ignore')
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2775531e-5f10-4931-8d5a-ab5c6c562437" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2775531e-5f10-4931-8d5a-ab5c6c562437">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ION Data Points - Sheet1.csv to ION Data Points - Sheet1 (2).csv

# %%
import pandas as pd
import io

train = pd.read_csv(io.StringIO(uploaded['ION Data Points - Sheet1.csv'].decode('utf-8')))
train
# Out:
#                                                Sector  Age Tv Bills   \
# 0                      Agriculture,forestry & fishing   23       Yes
# 1                                  Mining & quarrying   30       Yes
# 2                                       Manufacturing   35       Yes
# 3   Electricity, gas, water supply & other utility...   27       Yes
# 4   Public Administration, defence and other services   36       Yes
# 5   Public Administration, defence and other services   40       Yes
# 6                 Financial, real estate & prof servs   32       Yes
# 7   Public Administration, defence and other services   50       Yes
# 8   Public Administration, defence and other services   42       Yes
# 9                      Agriculture,forestry & fishing   23       Yes
# 10                     Agriculture,forestry & fishing   28       Yes
# 11                     Agriculture,forestry & fishing   29        No
# 12                     Agriculture,forestry & fishing   35       Yes
# 13                                       Construction   28        No
# 14  Trade, hotels, transport, communication and se...   43       Yes
# 15                                       Construction   26       Yes
# 16                                       Construction   23       Yes
# 17                                       Construction   25       Yes
# 18  Electricity, gas, water supply & other utility...   36       Yes
# 19  Public Administration, defence and other services   57       Yes
# 20  Public Administration, defence and other services   67        No
# 21  Public Administration, defence and other services   62       Yes
# 22  Public Administration, defence and other services   28       Yes
# 23  Public Administration, defence and other services   56       Yes
# 24  Electricity, gas, water supply & other utility...   26       Yes
# 25                Financial, real estate & prof servs   37       Yes
# 26                Financial, real estate & prof servs   46       Yes
# 27                                      Manufacturing   40       Yes
# 28                                 Mining & quarrying   27       Yes
# 29                                      Manufacturing   38       Yes
# 30                                       Construction   24       Yes
# 31                                      Manufacturing   45       Yes
# 32                                      Manufacturing   36       Yes
# 33                                      Manufacturing   54       Yes
# 34                                      Manufacturing   34       Yes
# 35  Electricity, gas, water supply & other utility...   26       Yes
# 36  Public Administration, defence and other services   45        No
# 37                Financial, real estate & prof servs   45       Yes
# 38                Financial, real estate & prof servs   32       Yes
# 39                Financial, real estate & prof servs   34       Yes
# 40  Electricity, gas, water supply & other utility...   25       Yes
# 41  Public Administration, defence and other services   36       Yes
# 42                     Agriculture,forestry & fishing   36       Yes
# 43                     Agriculture,forestry & fishing   26       Yes
# 44                     Agriculture,forestry & fishing   35        No
# 45                     Agriculture,forestry & fishing   25        No
# 46                                       Construction   23       Yes
# 47  Trade, hotels, transport, communication and se...   34       Yes
# 48                Financial, real estate & prof servs   56       Yes
#
#    Water bills Electricity Bills  Family Members  Group?  Duration (year)  \
# 0          Yes               Yes                6    Yes              2.0
# 1          Yes               Yes                5     No              1.0
# 2          Yes               Yes                6     No              3.0
# 3          Yes               Yes                4     No              1.0
# 4          Yes               Yes                3     No              1.0
# 5          Yes                No                4     No              2.0
# 6          Yes               Yes                4    Yes              1.0
# 7          Yes               Yes                8     No              2.5
# 8          Yes               Yes                5     No              1.0
# 9          Yes                No                4     No              1.5
# 10          No               Yes                4     No              1.0
# 11         Yes               Yes                4    Yes              0.5
# 12         Yes               Yes                5    Yes              1.5
# 13         Yes                No                3    Yes              1.0
# 14         Yes               Yes                5     No              2.0
# 15         Yes               Yes                3     No              1.0
# 16         Yes               Yes                4     No              1.0
# 17         Yes               Yes                4    Yes              1.0
# 18         Yes               Yes                5    Yes              1.0
# 19         Yes               Yes                6     No              2.0
# 20         Yes               Yes                6     No              2.0
# 21         Yes               Yes                5     No              3.0
# 22         Yes               Yes                4    Yes              1.0
# 23         Yes               Yes                5     No              2.5
# 24         Yes               Yes                4     No              1.0
# 25         Yes               Yes                5     No              1.0
# 26         Yes               Yes                7     No              2.0
# 27         Yes                No                6     No              4.0
# 28         Yes               Yes                5     No              2.0
# 29         Yes               Yes                4     No              3.0
# 30         Yes                No                4     No              1.0
# 31         Yes               Yes                6     No              3.0
# 32         Yes               Yes                7     No              2.0
# 33         Yes               Yes                6     No              3.0
# 34         Yes               Yes                4     No              2.5
# 35         Yes               Yes                4     No              2.0
# 36         Yes               Yes                8     No              4.0
# 37          No                No                5     No              5.0
# 38         Yes               Yes                4     No              2.0
# 39         Yes               Yes                3    Yes              3.0
# 40         Yes               Yes                4     No              1.5
# 41         Yes               Yes                6     No              2.0
# 42         Yes               Yes                5     No              1.0
# 43         Yes               Yes                4    Yes              3.0
# 44          No                No                4    Yes              2.0
# 45         Yes               Yes                3     No              2.0
# 46         Yes               Yes                5    Yes              1.0
# 47         Yes               Yes                4     No              5.0
# 48         Yes               Yes                6     No              2.0
#
#     Salary (yearly)    Qualifications      District             State  \
# 0            500000         Secondary      Amritsar            Punjab
# 1            200000           Diploma        Rohtak           Haryana
# 2           1000000    Undegraduation          Agra     Uttar Pradesh
# 3            600000    Undegraduation         Alwar         Rajasthan
# 4            800000    Postgraduation     Faridabad           Haryana
# 5            700000            Others         Patna             Bihar
# 6            600000    Undegraduation      Nainital  Himachal Pradesh
# 7            800000    Undegraduation       Kolkata       West Bengal
# 8           1200000    Undegraduation       Kolkata       West Bengal
# 9            300000  Senior Secondary      Gurugram           Haryana
# 10           600000  Senior Secondary      Gurugram           Haryana
# 11           800000           Diploma      Ludhiana            Punjab
# 12           500000           Diploma        Howrah       West Bengal
# 13           200000           Primary         Patna             Bihar
# 14          1500000    Postgraduation        Mumbai       Maharashtra
# 15           400000        Uneducated       Deogarh            Odisha
# 16           600000         Secondary     New Delhi             Delhi
# 17           300000           Primary        Ranchi         Jharkhand
# 18           500000    Postgraduation        Mumbai       Maharashtra
# 19           800000    Undegraduation       Jodhpur         Rajasthan
# 20          1000000    Undegraduation        Jaipur         Rajasthan
# 21           800000  Senior Secondary      Dehradun       Uttarakhand
# 22           900000    Postgraduation    Coimbatore        Tamil Nadu
# 23          1600000    Undegraduation       Chennai        Tamil Nadu
# 24           500000    Undegraduation    Coimbatore        Tamil Nadu
# 25           600000           Diploma        Bhopal    Madhya Pradesh
# 26           500000           Primary        Nagpur       Maharashtra
# 27          1500000         Secondary      Palakkad            Kerala
# 28           200000    Undegraduation         Kutch           Gujarat
# 29          1400000    Postgraduation     New Delhi             Delhi
# 30           200000    Postgraduation     Hyderabad         Karnataka
# 31           900000           Primary    Ahembdabad           Gujarat
# 32          1800000    Postgraduation      Banglore         Karnataka
# 33          1500000    Undegraduation        Mumbai       Maharashtra
# 34          1600000  Senior Secondary       Jodhpur         Rajasthan
# 35           600000  Senior Secondary        Luknow     Uttar Pradesh
# 36           900000  Senior Secondary  Bhubhneshwar            Odisha
# 37           900000    Undegraduation     New Delhi             Delhi
# 38           500000  Senior Secondary        Raipur      Chhattisgarh
# 39           700000    Undegraduation        Mumbai       Maharashtra
# 40           400000           Primary        Aizwal           Manipur
# 41           500000           Diploma        Aizwal           Manipur
# 42           200000        Uneducated        Bhopal    Madhya Pradesh
# 43           100000        Uneducated        Kohima          Nagaland
# 44           300000         Secondary      Jalandar            Punjab
# 45          1200000    Undegraduation        Ambala           Haryana
# 46           400000  Senior Secondary         Rachi         Jharkhand
# 47           600000    Undegraduation        Indore    Madhya Pradesh
# 48           300000            Others        Bhopal    Madhya Pradesh
#
#                     Loan History  Loan Category          Sector of Business  \
# 0   Loan taken and still repaying      Business                      Retail
# 1   Loan taken and still repaying       Medical                        None
# 2        Loan not taken / repayed      Business          Building Materials
# 3        Loan not taken / repayed     Education                        None
# 4       Loan not repayed on time.      Business      Information Technology
# 5   Loan taken and still repaying       Medical                        None
# 6   Loan taken and still repaying      Business               Capital Goods
# 7        Loan not taken / repayed     Education                        None
# 8        Loan not taken / repayed      Business          Textiles & Fashion
# 9       Loan not repayed on time.      Business                   Chemicals
# 10       Loan not taken / repayed      Business                  Healthcare
# 11  Loan taken and still repaying      Business         Industrial Products
# 12       Loan not taken / repayed      Business       Media & Entertainment
# 13  Loan taken and still repaying       Medical                        None
# 14       Loan not taken / repayed      Business  Transportation & Logistics
# 15  Loan taken and still repaying     Education                        None
# 16  Loan taken and still repaying       Medical                        None
# 17  Loan taken and still repaying     Education                        None
# 18       Loan not taken / repayed      Business                        None
# 19  Loan taken and still repaying       Medical                        None
# 20       Loan not taken / repayed       Medical                        None
# 21       Loan not taken / repayed     Education                        None
# 22  Loan taken and still repaying      Business             Metals & Mining
# 23       Loan not taken / repayed      Business          Consumers Durables
# 24       Loan not taken / repayed       Medical                        None
# 25       Loan not taken / repayed      Business          Textiles & Fashion
# 26       Loan not taken / repayed      Business       Tourism & Hospitality
# 27  Loan taken and still repaying      Business                   Chemicals
# 28      Loan not repayed on time.      Business          Textiles & Fashion
# 29       Loan not taken / repayed      Business                  Healthcare
# 30       Loan not taken / repayed     Education                        None
# 31  Loan taken and still repaying      Business                   FMCG-Food
# 32       Loan not taken / repayed       Medical                        None
# 33       Loan not taken / repayed      Business               Capital Goods
# 34       Loan not taken / repayed      Business      Information Technology
# 35       Loan not taken / repayed     Education                        None
# 36       Loan not taken / repayed       Medical                        None
# 37      Loan not repayed on time.      Business         Industrial Products
# 38  Loan taken and still repaying       Medical                        None
# 39  Loan taken and still repaying      Business                     Telecom
# 40       Loan not taken / repayed      Business  Transportation & Logistics
# 41  Loan taken and still repaying     Education                        None
# 42       Loan not taken / repayed      Business       Media & Entertainment
# 43  Loan taken and still repaying        Others                        None
# 44       Loan not taken / repayed     Education                        None
# 45       Loan not taken / repayed        Others                        None
# 46       Loan not taken / repayed      Business          Building Materials
# 47       Loan not taken / repayed      Business               Capital Goods
# 48       Loan not taken / repayed      Business                      Retail
#
#     Founding Year  Profit per anum  Credit Score  LOAN GRANTED    RISK SCORE
# 0            2013            40000             20            Yes          30
# 1               0                0             40            Yes          30
# 2            2020              100             10             No          85
# 3               0                0             20            Yes          30
# 4            2020           300000             60            Yes          20
# 5               0                0             10            Yes          40
# 6            2017           150000             80            Yes          35
# 7               0                0             20            Yes          45
# 8            2020            20000             30            Yes          50
# 9            2019           250000             70            Yes          20
# 10           2020           300000             60            Yes          20
# 11           2018           100000             40            Yes          30
# 12           2016           150000             50            Yes          20
# 13              0                0             30            Yes          40
# 14           2014            50000             60            Yes          40
# 15              0                0             90            Yes          45
# 16              0                0             70            Yes          40
# 17              0                0             30            Yes          45
# 18              0                0             10            Yes          50
# 19              0                0             20            Yes          45
# 20              0                0             40            Yes          50
# 21              0                0             20            Yes          50
# 22           2007           200000             10            Yes          30
# 23           2011            40000             40            Yes          50
# 24              0                0             50            Yes          50
# 25           2018            40000             20            Yes          45
# 26           2016           500000             20            Yes          20
# 27           2017           100000             20            Yes          20
# 28           2018            90000             40            Yes          35
# 29           2017           200000             30            Yes          20
# 30              0                0             70            Yes          30
# 31           2021            20000             90            Yes          30
# 32              0                0             60            Yes          25
# 33           2009           200000             40            Yes          20
# 34           2017           600000             50            Yes          10
# 35              0                0             20            Yes          60
# 36              0                0             40            Yes          50
# 37           2020            40000             30            Yes          40
# 38              0                0             10            Yes          60
# 39           2016            60000             60            Yes          30
# 40           2017           100000              0             No          75
# 41              0                0              0             No          80
# 42           2019           500000             20            Yes          20
# 43              0                0             30            Yes          45
# 44              0                0             20            Yes          50
# 45              0                0             40            Yes          40
# 46           2016            40000             50            Yes          25
# 47           2020            30000             50            Yes          35
# 48           2019           120000             80            Yes          10

# %%
train.replace("Yes",1,inplace=True)

# %%
train.replace("No",0,inplace=True)

# %%
train.replace(["Maharashtra","Tamil Nadu","Uttar Pradesh","Gujarat","Karnataka","West Bengal","Rajasthan","Andhra Pradesh","Telangana","Madhya Pradesh","Kerala","Delhi"],10,inplace=True)

# %%
train.replace(["Haryana","Bihar", "Punjab","Odisha","Assam","Chhattisgarh","Jharkhand","Uttarakhand","Jammu & Kashmir","Himachal Pradesh","Goa","Tripura","Chandigarh","Puducherry","Meghalaya","Sikkim","Manipur","Nagaland","Arunachal Pradesh","Mizoram","Andaman & Nicobar Islands"],5,inplace=True)

# %%
train.replace("Primary",1,inplace=True)

# %%
train.replace("Uneducated",-1,inplace=True)
train.replace("Secondary",2,inplace=True)
train.replace("Diploma",4,inplace=True)
train.replace("Undegraduation",5,inplace=True)
train.replace("Postgraduation",6,inplace=True)
train.replace("Others",7,inplace=True)
train.replace("Primary",1,inplace=True)
train.replace("Senior Secondary",3,inplace=True)

train.replace("Loan taken and still repaying",0,inplace=True)
train.replace("Loan not taken / repayed",1,inplace=True)
train.replace("Loan not repayed on time.",-3,inplace=True)

train.replace("Business",5,inplace=True)
train.replace("Education",4,inplace=True)
train.replace("Medical",3,inplace=True)
train.replace("Others",1,inplace=True)

train.replace("Agriculture,forestry & fishing",2.56,inplace=True)
train.replace("Mining & quarrying",0.28,inplace=True)
train.replace("Manufacturing",5.28,inplace=True)
train.replace("Electricity, gas, water supply & other utility services",8.01,inplace=True)
train.replace("Construction",6.34,inplace=True)
train.replace("Trade, hotels, transport, communication and services related to broadcasting",7.14,inplace=True)
train.replace("Financial, real estate & prof servs",7.16,inplace=True)
train.replace("Public Administration, defence and other services",7.39,inplace=True)


train.replace("Auto Components",6.1,inplace=True)
train.replace("Automotive",16.2,inplace=True)
train.replace("Building Materials",3.4,inplace=True)
train.replace("Capital Goods",-2.7,inplace=True)
train.replace("Chemicals",4.9,inplace=True)
train.replace("Construction",-0.6,inplace=True)
train.replace("Consumers Durables",1.9,inplace=True)
train.replace("Diversified",2.9,inplace=True)
train.replace("FMGC-Non-food",5,inplace=True)
train.replace("FMCG-Food",2.1,inplace=True)
train.replace("Forest Materials",0.3,inplace=True)
train.replace("Healthcare",11.5,inplace=True)
train.replace("Industrial Products",0.8,inplace=True)
train.replace("Information Technology",26,inplace=True)
train.replace("Media & Entertainment",2.1,inplace=True)
train.replace("Metals & Mining",-1.2,inplace=True)
train.replace("Retail",1.5,inplace=True)
train.replace("Telecom",3.2,inplace=True)
train.replace("Textiles & Fashion",1.6,inplace=True)
train.replace("Tourism & Hospitality",-0.4,inplace=True)
train.replace("Transportation & Logistics",0.4,inplace=True)
train.replace("Utilities",14.9,inplace=True)
train.replace("None",0,inplace=True)

# %%
train['District'] = train.District.map( lambda x: 1 if x == "Amaravati"or x == "Itanagar" or x == "Dispur" or x == "Patna" or x == "Raipur" or x == "Panaji" or x == "Gandhinagar" or x == "Chandigarh" or x == "Shimla" or x == "Ranchi" or x == "Hyderabad" or x == "Agartala" or x == "Lucknow" or x =="Dehradun" or x =="Kolkata" or x =="Aizawl" or x =="Kohima" or x =="Bhubaneswar" or x =="Chandigarh" or x =="Jaipur" or x=="Gangtok" or x =="Chennai" or x =="Hyderabad" or x == "Gandhinagar" or x =="Chandigarh" or x == "Shimla" or x =="Ranchi" or x =="Bengaluru" or x =="Thiruvananthapuram" or x =="Bhopal" or x =="Mumbai" else 0)

# %%
train.dtypes
# Out:
# Sector                float64
# Age                     int64
# Tv Bills                int64
# Water bills             int64
# Electricity Bills       int64
# Family Members          int64
# Group?                  int64
# Duration (year)       float64
# Salary (yearly)         int64
# Qualifications          int64
# District                int64
# State                   int64
# Loan History            int64
# Loan Category           int64
# Sector of Business    float64
# Founding Year           int64
# Profit per anum         int64
# Credit Score            int64
# LOAN GRANTED            int64
# RISK SCORE              int64
# dtype: object

# %%
train
# Out:
#     Sector  Age  Tv Bills   Water bills  Electricity Bills  Family Members   \
# 0     2.56   23          1            1                  1                6
# 1     0.28   30          1            1                  1                5
# 2     5.28   35          1            1                  1                6
# 3     8.01   27          1            1                  1                4
# 4     7.39   36          1            1                  1                3
# 5     7.39   40          1            1                  0                4
# 6     7.16   32          1            1                  1                4
# 7     7.39   50          1            1                  1                8
# 8     7.39   42          1            1                  1                5
# 9     2.56   23          1            1                  0                4
# 10    2.56   28          1            0                  1                4
# 11    2.56   29          0            1                  1                4
# 12    2.56   35          1            1                  1                5
# 13    6.34   28          0            1                  0                3
# 14    7.14   43          1            1                  1                5
# 15    6.34   26          1            1                  1                3
# 16    6.34   23          1            1                  1                4
# 17    6.34   25          1            1                  1                4
# 18    8.01   36          1            1                  1                5
# 19    7.39   57          1            1                  1                6
# 20    7.39   67          0            1                  1                6
# 21    7.39   62          1            1                  1                5
# 22    7.39   28          1            1                  1                4
# 23    7.39   56          1            1                  1                5
# 24    8.01   26          1            1                  1                4
# 25    7.16   37          1            1                  1                5
# 26    7.16   46          1            1                  1                7
# 27    5.28   40          1            1                  0                6
# 28    0.28   27          1            1                  1                5
# 29    5.28   38          1            1                  1                4
# 30    6.34   24          1            1                  0                4
# 31    5.28   45          1            1                  1                6
# 32    5.28   36          1            1                  1                7
# 33    5.28   54          1            1                  1                6
# 34    5.28   34          1            1                  1                4
# 35    8.01   26          1            1                  1                4
# 36    7.39   45          0            1                  1                8
# 37    7.16   45          1            0                  0                5
# 38    7.16   32          1            1                  1                4
# 39    7.16   34          1            1                  1                3
# 40    8.01   25          1            1                  1                4
# 41    7.39   36          1            1                  1                6
# 42    2.56   36          1            1                  1                5
# 43    2.56   26          1            1                  1                4
# 44    2.56   35          0            0                  0                4
# 45    2.56   25          0            1                  1                3
# 46    6.34   23          1            1                  1                5
# 47    7.14   34          1            1                  1                4
# 48    7.16   56          1            1                  1                6
#
#     Group?  Duration (year)  Salary (yearly)  Qualifications  District  State  \
# 0        1              2.0           500000               2         0      5
# 1        0              1.0           200000               4         0      5
# 2        0              3.0          1000000               5         0     10
# 3        0              1.0           600000               5         0     10
# 4        0              1.0           800000               6         0      5
# 5        0              2.0           700000               7         1      5
# 6        1              1.0           600000               5         0      5
# 7        0              2.5           800000               5         1     10
# 8        0              1.0          1200000               5         1     10
# 9        0              1.5           300000               3         0      5
# 10       0              1.0           600000               3         0      5
# 11       1              0.5           800000               4         0      5
# 12       1              1.5           500000               4         0     10
# 13       1              1.0           200000               1         1      5
# 14       0              2.0          1500000               6         1     10
# 15       0              1.0           400000              -1         0      5
# 16       0              1.0           600000               2         0     10
# 17       1              1.0           300000               1         1      5
# 18       1              1.0           500000               6         1     10
# 19       0              2.0           800000               5         0     10
# 20       0              2.0          1000000               5         1     10
# 21       0              3.0           800000               3         1      5
# 22       1              1.0           900000               6         0     10
# 23       0              2.5          1600000               5         1     10
# 24       0              1.0           500000               5         0     10
# 25       0              1.0           600000               4         1     10
# 26       0              2.0           500000               1         0     10
# 27       0              4.0          1500000               2         0     10
# 28       0              2.0           200000               5         0     10
# 29       0              3.0          1400000               6         0     10
# 30       0              1.0           200000               6         1     10
# 31       0              3.0           900000               1         0     10
# 32       0              2.0          1800000               6         0     10
# 33       0              3.0          1500000               5         1     10
# 34       0              2.5          1600000               3         0     10
# 35       0              2.0           600000               3         0     10
# 36       0              4.0           900000               3         0      5
# 37       0              5.0           900000               5         0     10
# 38       0              2.0           500000               3         1      5
# 39       1              3.0           700000               5         1     10
# 40       0              1.5           400000               1         0      5
# 41       0              2.0           500000               4         0      5
# 42       0              1.0           200000              -1         1     10
# 43       1              3.0           100000              -1         1      5
# 44       1              2.0           300000               2         0      5
# 45       0              2.0          1200000               5         0      5
# 46       1              1.0           400000               3         0      5
# 47       0              5.0           600000               5         0     10
# 48       0              2.0           300000               7         1     10
#
#     Loan History   Loan Category  Sector of Business  Founding Year  \
# 0               0              5                 1.5           2013
# 1               0              3                 0.0              0
# 2               1              5                 3.4           2020
# 3               1              4                 0.0              0
# 4              -3              5                26.0           2020
# 5               0              3                 0.0              0
# 6               0              5                -2.7           2017
# 7               1              4                 0.0              0
# 8               1              5                 1.6           2020
# 9              -3              5                 4.9           2019
# 10              1              5                11.5           2020
# 11              0              5                 0.8           2018
# 12              1              5                 2.1           2016
# 13              0              3                 0.0              0
# 14              1              5                 0.4           2014
# 15              0              4                 0.0              0
# 16              0              3                 0.0              0
# 17              0              4                 0.0              0
# 18              1              5                 0.0              0
# 19              0              3                 0.0              0
# 20              1              3                 0.0              0
# 21              1              4                 0.0              0
# 22              0              5                -1.2           2007
# 23              1              5                 1.9           2011
# 24              1              3                 0.0              0
# 25              1              5                 1.6           2018
# 26              1              5                -0.4           2016
# 27              0              5                 4.9           2017
# 28             -3              5                 1.6           2018
# 29              1              5                11.5           2017
# 30              1              4                 0.0              0
# 31              0              5                 2.1           2021
# 32              1              3                 0.0              0
# 33              1              5                -2.7           2009
# 34              1              5                26.0           2017
# 35              1              4                 0.0              0
# 36              1              3                 0.0              0
# 37             -3              5                 0.8           2020
# 38              0              3                 0.0              0
# 39              0              5                 3.2           2016
# 40              1              5                 0.4           2017
# 41              0              4                 0.0              0
# 42              1              5                 2.1           2019
# 43              0              7                 0.0              0
# 44              1              4                 0.0              0
# 45              1              7                 0.0              0
# 46              1              5                 3.4           2016
# 47              1              5                -2.7           2020
# 48              1              5                 1.5           2019
#
#     Profit per anum  Credit Score   LOAN GRANTED    RISK SCORE
# 0             40000             20               1          30
# 1                 0             40               1          30
# 2               100             10               0          85
# 3                 0             20               1          30
# 4            300000             60               1          20
# 5                 0             10               1          40
# 6            150000             80               1          35
# 7                 0             20               1          45
# 8             20000             30               1          50
# 9            250000             70               1          20
# 10           300000             60               1          20
# 11           100000             40               1          30
# 12           150000             50               1          20
# 13                0             30               1          40
# 14            50000             60               1          40
# 15                0             90               1          45
# 16                0             70               1          40
# 17                0             30               1          45
# 18                0             10               1          50
# 19                0             20               1          45
# 20                0             40               1          50
# 21                0             20               1          50
# 22           200000             10               1          30
# 23            40000             40               1          50
# 24                0             50               1          50
# 25            40000             20               1          45
# 26           500000             20               1          20
# 27           100000             20               1          20
# 28            90000             40               1          35
# 29           200000             30               1          20
# 30                0             70               1          30
# 31            20000             90               1          30
# 32                0             60               1          25
# 33           200000             40               1          20
# 34           600000             50               1          10
# 35                0             20               1          60
# 36                0             40               1          50
# 37            40000             30               1          40
# 38                0             10               1          60
# 39            60000             60               1          30
# 40           100000              0               0          75
# 41                0              0               0          80
# 42           500000             20               1          20
# 43                0             30               1          45
# 44                0             20               1          50
# 45                0             40               1          40
# 46            40000             50               1          25
# 47            30000             50               1          35
# 48           120000             80               1          10

# %%
y_train=train['RISK SCORE']
y_train_1=train['LOAN GRANTED  ']

# %%
print(train.columns.tolist())
# Out:
# ['Sector', 'Age', 'Tv Bills ', 'Water bills', 'Electricity Bills', 'Family Members ', 'Group?', 'Duration (year)', 'Salary (yearly)', 'Qualifications', 'District', 'State', 'Loan History ', 'Loan Category', 'Sector of Business', 'Founding Year', 'Profit per anum', 'Credit Score ', 'LOAN GRANTED  ', 'RISK SCORE']

# %%
x_train=train.drop(['LOAN GRANTED  ', 'RISK SCORE'], axis = 1)

# %%
x_train.shape
# Out:
# (49, 18)

# %%
from sklearn.linear_model import LogisticRegression 
classifier = LogisticRegression(random_state = 0) 
classifier.fit(x_train, y_train_1)
# Out:
# LogisticRegression(random_state=0)

# %%
from sklearn.linear_model import LinearRegression 
rs = LinearRegression() 
rs.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **EXAMPLE**

# %%
pred=rs.predict([[7.16,45,1,0,0,5,0,5.0,900000,5,0,10,-3,5,0.8,2020,400,1]])

# %%
print(pred)
# Out:
# [56.09433983]

# %% [markdown]
# **PICKLE**

# %%
import pickle

# %%
pickle.dump(rs,open('model1.pk1','wb'))

# %%
pickle.dump(classifier,open('model2.pk1','wb'))
